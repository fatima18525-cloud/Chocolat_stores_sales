# %%
import pandas as pd

# %%
data = [['قلم', 1, 1, 'حنان'],
        ['شنطة', 2, 2, 'صفاء']]
df = pd.DataFrame(data, columns = ['نوع الهدية', 'عدد الهدايا', 'العدد الإحمالي البعدي','اسم المسلمة'])

# %%
df.to_csv("gifts.csv")
